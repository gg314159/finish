# %%
import pandas as pd
import numpy as np
f = pd.read_excel("/home/gc/gechang/final_final/filelist/testadcnmci.xlsx")

# %%
import cv2
for index, row in f.iterrows():
    mri = cv2.imread(row['mripath'])
    pet = cv2.imread(row['petpath'])
    print(mri.shape)
    print(pet.shape)
    if(type(mri)!=np.ndarray):
        print(type(mri))
        print(type(pet))
        print(row)
# Out:
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# (436, 364, 3)
# (872, 728, 3)
# ...
